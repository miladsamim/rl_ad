# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
reward_df = pd.read_csv('ddqn_reward_training.csv')
time_df = pd.read_csv('ddqn_ep_time_training.csv')

# %%
reward_df.diff(1)['Step'].plot()
# Out:
# <AxesSubplot: >

# %%
time_df
# Out:
#         Wall time  Step         Value
# 0    1.667832e+09     5     55.944820
# 1    1.667832e+09     6     66.410355
# 2    1.667832e+09    11    119.780510
# 3    1.667832e+09    14    151.324661
# 4    1.667832e+09    15    162.177795
# ..            ...   ...           ...
# 995  1.667926e+09  2979  93580.671875
# 996  1.667926e+09  2988  93691.976562
# 997  1.667926e+09  2994  93766.750000
# 998  1.667926e+09  2998  93814.562500
# 999  1.667926e+09  2999  93827.054688
#
# [1000 rows x 3 columns]
